# %% [markdown]
# pruebas

# %% [markdown]
# Escribe un programa que solicite al usuario dos números por teclado (usando input). Convierte el primero a entero y el segundo a flotante. Muestra por pantalla la suma de ambos y el tipo de dato del resultado final

# %%
entero = int(input("Ingrese un numero :"))
decimal = float(input("Ingrese un numero :"))
suma = entero + decimal
print(suma)
print(type(suma) )
# Out:
# Ingrese un numero : 4
# Ingrese un numero : 4
# 8.0
# <class 'float'>

# %%
# Pedimos los datos y los convertimos en la misma línea (anidamiento)
# int() y float() envuelven al input() [cite: 250, 256, 378]
suma = int(input("Ingrese un numero entero: ")) + float(input("Ingrese un numero decimal: "))

# Mostramos el resultado y el tipo de dato final [cite: 89, 106]
print(f"La suma es: {suma}", type(suma))

# %% [markdown]
# El Reto
# Dada la variable s = "Aprendiendo Python 2026", haz un programa que:
#
# Extraiga solo la palabra "Python".
#
# Muestre toda la frase al revés (invertida).

# %%
s = "Aprendiendo Python 2026"

# 1. Extraer "Python"
# Cuenta: A=0, p=1, r=2... ¿en qué posición está la P?
palabra = s[12:18] 

# 2. Invertir la frase
invertida = s[::-1] 

print(palabra)
print(invertida)
# Out:
# Python
# 6202 nohtyP odneidnerpA

# %% [markdown]
# El Reto: "El Código Secreto"
# Imagina que tienes la siguiente cadena de texto: mensaje = "ERROR_Zona_51_Detectada"
#
# Tu tarea es:
#
#
# Extraer solo la palabra "Zona".
#
#
# Extraer solo el número "51".
#
#
# Invertir solo la palabra "ERROR".
#
#
# Unir (concatenar) la palabra "Zona" con el número "51" usando un espacio en medio para que diga "Zona 51".

# %%
l = "ERROR_Zona_51_Detectada"

extraer = l[6:10]
print(extraer)
extraer2 = l[11:13]
print(extraer)
extraer3 = l[:5]
error_inv = l[4::-1]
print(f"Invertido: {error_inv}")
print(extraer3)
print(l[6:10] +" "+ l[11:13])
# Out:
# Zona
# Zona
# Invertido: RORRE
# ERROR
# Zona 51

# %% [markdown]
# El Reto: "¿Gemelos o el Mismo?"
# Copia y completa este código siguiendo estas instrucciones:
#
# Crea una lista llamada L1 con los valores [10, 20, 30].
#
# Crea una variable L2 que sea un alias de L1 (simplemente haz L2 = L1).
# +1
#
# Crea una variable L3 que sea una copia de L1 (usa el método L1.copy() o el slicing L1[:]).
# +4
#
# Usa el operador is para comparar si L1 es lo mismo que L2.
# +1
#
# Usa el operador is para comparar si L1 es lo mismo que L3.

# %%
L1 = [10,20,30]
L2 = L1
L3 = L1.copy()

# Comparaciones de identidad
print(f"¿L1 es L2?: {L1 is L2}") 
print(f"¿L1 es L3?: {L1 is L3}")

# Pista extra: mira sus IDs para confirmar
print(id(L1))
print(id(L2))
print(id(L3))
# Out:
# ¿L1 es L2?: True
# ¿L1 es L3?: False
# 2929303845056
# 2929303845056
# 2929303940224

# %% [markdown]
# "Inventario de la Tienda"
# Crea un programa que gestione un producto de una tienda siguiendo estos pasos:
#
# Crea un diccionario llamado producto con estos datos iniciales: nombre es "Laptop", precio es 800, y stock es 10.
#
#
# Añade una nueva clave llamada categoria que sea "Electrónica".
#
#
# Modifica el precio aumentándole el 10% (pista: usa += o multiplica).
# +1
#
#
# Busca una clave que no existe (por ejemplo, descuento) usando el método .get() para que no se te cierre el programa por error y que devuelva 0 por defecto.
# +1
#
# 💡 Pistas del Pana (basadas en el PDF):
#
# Creación: Usa llaves {} y separa clave de valor con dos puntos :.
#
#
# Añadir/Modificar: Es igual, solo pon diccionario['clave'] = nuevo_valor.
# +1
#
#
# Evitar errores: Si haces producto['descuento'] y no existe, el programa "muere". Por eso el PDF recomienda usar .get('clave', valor_por_defecto).
# +2

# %%
diccionario = {'nombre':'laptop', 'precio' : 800 , 'stock' : 10}
# 2. Añadir categoría
diccionario["categoria"] = "electronica"

# 3. Subir el precio un 10% (precio * 1.10)
diccionario["precio"] = (* 1.10)

# 4. Usar .get() para el descuento
desc = diccionario.get("descuento", 0)

print(diccionario)
print(f"El descuento es: {desc}")
# Out:
#   Cell In[43], line 6
#     diccionario["precio"] = (* 1.10)
#                              ^
# SyntaxError: cannot use starred expression here
